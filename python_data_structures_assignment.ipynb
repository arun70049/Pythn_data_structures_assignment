# %%
# Q 1. Discuss string slicing and provide examples.

''' ANS: String slicing is a powerful feature in Python that allows us to
extract parts of a string by specifying a start, stop, and step value.
 It's a concise way to get substrings or manipulate strings.
 
Basic Syntax
The syntax for slicing a string is:
string[start:stop:step] 

start: The index where the slice starts (inclusive).
stop: The index where the slice ends (exclusive).
step: The step between each index to include in the slice.
If any of these parameters are omitted, Python provides default values:

start defaults to 0 if omitted.
stop defaults to the end of the string if omitted.
step defaults to 1 if omitted.

Examples
examples to illustrate how string slicing works.

Basic Slicing '''


s = "Hello, World!"
print(s[0:5])  # Output: Hello

# Here, s[0:5] extracts the substring from index 0 up to,
but not including,index 5.

# Omitting Parameters


s = "Hello, World!"
print(s[:5])   # Output: Hello
print(s[7:])   # Output: World!
print(s[:])    # Output: Hello, World!

''' s[:5] gets the substring from the beginning up to index 5.
s[7:] gets the substring from index 7 to the end.
s[:] gets the whole string. '''

# Using Step

s = "Hello, World!"
print(s[::2])  # Output: Hlo ol!
print(s[1:10:2])  # Output: el,W

# s[::2] takes every second character from the string.
# s[1:10:2] takes every second character from index 1 to 9.

# Negative Indices

s = "Hello, World!"
print(s[-6:-1])  # Output: World
print(s[::-1])   # Output: !dlroW ,olleH

""" s[-6:-1] extracts the substring from the 6th character from the end up to,
but not including, the last character.
 s[::-1] reverses the entire string.
 Slicing with Different Steps """


s = "1234567890"
print(s[::3])  # Output: 1470
print(s[1::3])  # Output: 2589

# s[::3] extracts every 3rd character starting from index 0.
# s[1::3] extracts every 3rd character starting from index 1.

 # Insights:
# String slicing is a versatile tool in 
Python that lets you efficiently extract and manipulate parts of strings.
# Out:
# Hello
# Hello
# World!
# Hello, World!
# Hlo ol!
# el,Wr
# World
# !dlroW ,olleH
# 1470
# 258

# %%
# Q 2. Explain the key features of lists in  python.

''' ANS: Lists in Python are a versatile and widely used data structure
that can store a collection of items. They are particularly useful due to their 
dynamic nature and the broad range of operations they support.
Here are the key features of lists in Python:

1. Ordered
Lists maintain the order of elements.
This means that the order in which you add items to the list is the order in which 
they are stored and retrieved.

Example: '''

my_list = [10, 20, 30]
print(my_list[0])  # Output: 10

''' 2. Mutable
Lists are mutable, meaning that you can change their content after they have been created. You can add, remove, or modify items in a list.

Examples:  '''


# Modifying elements
my_list = [10, 20, 30]
my_list[1] = 25
print(my_list)  # Output: [10, 25, 30]

# Adding elements
my_list.append(40)
print(my_list)  # Output: [10, 25, 30, 40]

# Removing elements
my_list.remove(25)
print(my_list)  # Output: [10, 30, 40]

''' 3. Dynamic Size
Lists in Python can grow and shrink in size as needed.
We don’t need to define their size when you create them.

Example: '''

my_list = []
my_list.append(1)
my_list.append(2)
print(my_list)  # Output: [1, 2]

''' 4. Heterogeneous
Lists can contain items of different data types, including other lists.

Example: '''

my_list = [1, "Hello", 3.14, [2, 4, 6]]
print(my_list[3])  # Output: [2, 4, 6]


''' 5. Indexing and Slicing
Lists support indexing and slicing, allowing you to access and modify subsets 
of the list. '''

# Examples: 

my_list = [10, 20, 30, 40, 50]
print(my_list[1:4])  # Output: [20, 30, 40]

# Negative indexing
print(my_list[-1])  # Output: 50
print(my_list[-3:-1])  # Output: [30, 40]

''' 6. Iterable
Lists are iterable, which means you can use them in loops and other contexts where
iteration is required. '''

# Example:


my_list = [1, 2, 3, 4, 5]
for item in my_list:
    print(item)
    
''' 7. Various Built-in Methods
Python lists come with a number of built-in methods for common operations: '''

# append(x): Adds an item to the end of the list.
#       extend(iterable): Extends the list by appending elements from an iterable.
# insert(i, x): Inserts an item at a specified position.
# remove(x): Removes the first occurrence of an item.
# pop([i]): Removes and returns an item at the specified position (or the last item if no index is provided).
# clear(): Removes all items from the list.
# index(x[, start[, end]]): Returns the index of the first occurrence of an item.
# count(x): Returns the number of occurrences of an item.
# sort(key=None, reverse=False): Sorts the items in place.
# reverse(): Reverses the items in place.
# copy(): Returns a shallow copy of the list.

#Examples:

my_list = [1, 2, 3, 4, 5]

my_list.append(6)
print(my_list)  # Output: [1, 2, 3, 4, 5, 6]

my_list.insert(2, 10)
print(my_list)  # Output: [1, 2, 10, 3, 4, 5, 6]

my_list.remove(10)
print(my_list)  # Output: [1, 2, 3, 4, 5, 6]

print(my_list.pop())  # Output: 6
print(my_list)  # Output: [1, 2, 3, 4, 5]

#  Insights:
    
''' Python lists are highly flexible and useful for managing collections of items.
Their key features include their ordered nature, mutability, dynamic size,
ability to hold heterogeneous data types, support for indexing and slicing,
and a rich set of built-in methods. '''

# %%
# Q 3. Describe how to access, modify and delete elements in a list with examples.

''' ANS: In Python, you can access, modify, and delete elements in a list using 
various techniques.
Explanation of each operation with examples:

1. Accessing Elements
We can access elements in a list using indexing.
Python lists are zero-indexed, which means the first element has an index of 0. '''

# Examples:

my_list = ['apple', 'banana', 'cherry']

# Accessing elements using positive indices
print(my_list[0])  # Output: apple
print(my_list[1])  # Output: banana

# Accessing elements using negative indices (counts from the end)
print(my_list[-1])  # Output: cherry
print(my_list[-2])  # Output: banana

# Accessing a range of elements using slicing
print(my_list[1:3])  # Output: ['banana', 'cherry']

''' 2. Modifying Elements
We can modify elements in a list by assigning a new value to a specific index.
We can also use slicing to modify multiple elements at once. '''

# Examples:

my_list = [10, 20, 30, 40, 50]

# Modifying a single element
my_list[2] = 35
print(my_list)  # Output: [10, 20, 35, 40, 50]

# Modifying elements using slicing
my_list[1:4] = [25, 30, 45]
print(my_list)  # Output: [10, 25, 30, 45, 50]

# Modifying with a different length
my_list[1:3] = [27, 33, 37]
print(my_list)  # Output: [10, 27, 33, 37, 45, 50]

''' 3. Deleting Elements
We can delete elements from a list using several methods: '''

# Using del Statement: Deletes an element by index or a slice of elements.
# Using remove() Method: Removes the first occurrence of a specific value.
# Using pop() Method: Removes and returns an element at a specific index or
#                     the last element if no index is specified.
# Using clear() Method: Removes all elements from the list. 

#Examples:

my_list = ['apple', 'banana', 'cherry', 'date']

# Deleting an element by index
del my_list[1]
print(my_list)  # Output: ['apple', 'cherry', 'date']

# Deleting a slice of elements
del my_list[0:2]
print(my_list)  # Output: ['date']

# Removing an element by value
my_list = ['apple', 'banana', 'cherry']
my_list.remove('banana')
print(my_list)  # Output: ['apple', 'cherry']

# Removing and returning an element by index
popped_element = my_list.pop(0)
print(popped_element)  # Output: apple
print(my_list)  # Output: ['cherry']

# Removing and returning the last element
last_element = my_list.pop()
print(last_element)  # Output: cherry
print(my_list)  # Output: []

# Clearing all elements
my_list = ['apple', 'banana', 'cherry']
my_list.clear()
print(my_list)  # Output: []
# Insights
# Accessing Elements: Use indexing (list[index]) or slicing (list[start:stop]).
# Modifying Elements: Assign new values using indexing or slicing (list[index] = value or list[start:stop] = new_values).
# Deleting Elements: Use del list[index], list.remove(value), list.pop([index]), or list.clear().
# Out:
# apple
# banana
# cherry
# banana
# ['banana', 'cherry']
# [10, 20, 35, 40, 50]
# [10, 25, 30, 45, 50]
# [10, 27, 33, 37, 45, 50]
# ['apple', 'cherry', 'date']
# ['date']
# ['apple', 'cherry']
# apple
# ['cherry']
# cherry
# []
# []

# %%
# Q 4. Compare and contrast tuples and lists with examples.

''' ANS: Tuples and lists are both fundamental data structures in Python 
that are used to store collections of items. 
While they share some similarities, they also have key differences that make 
each suitable for different use cases.
Here's a detailed comparison: '''

''' 1. Mutability
Lists: Lists are mutable, meaning you can change their content after they are created.
This includes adding, removing, or modifying elements.'''

# Example:

my_list = [1, 2, 3]
my_list[1] = 20
my_list.append(4)
print(my_list)  # Output: [1, 20, 3, 4]

''' Tuples: Tuples are immutable, meaning once they are created, 
their content cannot be changed.
This includes not being able to add, remove, or modify elements. '''

# Example:

my_tuple = (1, 2, 3)

# my_tuple[1] = 20  # This will raise a TypeError
# my_tuple.append(4)  # This will also raise an AttributeError

# 2. Syntax
# Lists: Lists are created using square brackets [].

# Example:


my_list = [1, 2, 3, 4]

''' Tuples: Tuples are created using parentheses ().
A single-element tuple requires a trailing comma to differentiate 
it from a single value in parentheses. '''

# Example:

my_tuple = (1, 2, 3, 4)
single_element_tuple = (1,)  # Note the trailing comma

''' 3. Performance
Lists: Due to their mutable nature, lists typically have a slightly higher overhead compared to tuples.
Operations like appending or modifying elements are more flexible but come with a cost in terms of performance.

# Tuples: Tuples are generally faster than lists because they are immutable.
The fixed size and immutability allow for optimizations by the Python interpreter,
making them more efficient in terms of performance.

 4. Use Cases
Lists: Use lists when you need a collection of items that may change over time.
They are ideal for situations where you need to add, remove, or modify elements. '''

# Example:

# List of tasks to complete
tasks = ['do laundry', 'write report', 'call mom']
tasks.append('buy groceries')

''' Tuples: Use tuples when you need a fixed collection of items that should not change.
They are suitable for representing fixed records or groupings of related data that shouldn’t be altered. '''

# Example:

# Coordinates of a point in 2D space
point = (3, 4)

# Record of a person's information
person = ('John Doe', 30, 'Engineer')

''' 5. Methods and Operations
Lists: Lists come with a variety of built-in methods such as append(), remove(),
extend(), pop(), reverse(), and sort().
These methods support a wide range of operations. '''

# Example:

my_list = [1, 2, 3]
my_list.append(4)
my_list.remove(2)
my_list.sort(reverse=True)
print(my_list)  # Output: [4, 3, 1]

''' Tuples: Tuples have fewer methods available.
They support count() and index() methods but do not have methods to modify their content.
'''

# Example:

my_tuple = (1, 2, 3, 1, 2)
print(my_tuple.count(1))  # Output: 2
print(my_tuple.index(2))  # Output: 1

''' 6. Nesting
Lists: Lists can contain other lists, creating multi-dimensional lists.'''

# Example:

nested_list = [[1, 2], [3, 4], [5, 6]]
print(nested_list[1])  # Output: [3, 4]

# Tuples: Tuples can also contain other tuples or lists.

# Example:

nested_tuple = ((1, 2), (3, 4), (5, 6))
print(nested_tuple[1])  # Output: (3, 4)

''' Insights
Lists: Mutable, created with [], have many methods for modification, 
and are generally used for collections that change over time.

Tuples: Immutable, created with (), have fewer methods, and are used for fixed collections of items. '''
# Out:
# [1, 20, 3, 4]
# [4, 3, 1]
# 2
# 1
# [3, 4]
# (3, 4)
# ' Insights\nLists: Mutable, created with [], have many methods for modification, \nand are generally used for collections that change over time.\n\nTuples: Immutable, created with (), have fewer methods, and are used for fixed collections of items. '

# %%
# Q 5. Describe the key features of sets and provide examples of their use.

''' ANS: Sets in Python are a powerful and versatile data structure used to store
unordered collections of unique items.
They are particularly useful when we need to manage collections of items without 
duplicates and perform operations like union, intersection, and difference.

Key features of sets, along with examples of their use:

Key Features of Sets
(a) Unordered Collection

Sets do not maintain any order of elements.
The items in a set do not have an index, and their order can change.
'''

# Example:

my_set = {1, 2, 3, 4}
print(my_set)  # Output: {1, 2, 3, 4}

''' (b)Unique Elements

Sets automatically ensure that all elements are unique.
Duplicate values are ignored when adding elements to a set. '''

#Example:

my_set = {1, 2, 3, 2, 1}
print(my_set)  # Output: {1, 2, 3}

''' (c) Mutable

Sets are mutable, meaning we can add or remove elements after creation.
However, the elements themselves must be immutable (e.g., numbers, strings, tuples).'''

#Example:

my_set = {1, 2, 3}
my_set.add(4)
my_set.remove(2)
print(my_set)  # Output: {1, 3, 4}

''' (d) No Duplicate Values

Sets automatically handle duplicates and only store unique values. '''

# Example:

my_set = {1, 1, 2, 3, 3}
print(my_set)  # Output: {1, 2, 3}

''' (e)Dynamic Size

Sets can grow and shrink in size dynamically as we add or remove elements. '''

# Example:

my_set = {1, 2}
my_set.add(3)
my_set.discard(1)
print(my_set)  # Output: {2, 3}

''' Set Operations

Sets support various set operations like union, intersection, difference,
and symmetric difference.'''

# Examples:

# Union: Combines elements from two sets, excluding duplicates.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1 | set2
print(union_set)  # Output: {1, 2, 3, 4, 5}

# Intersection: Finds common elements between two sets.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
intersection_set = set1 & set2
print(intersection_set)  # Output: {3}

# Difference: Finds elements that are in the first set but not in the second.


set1 = {1, 2, 3}
set2 = {3, 4, 5}
difference_set = set1 - set2
print(difference_set)  # Output: {1, 2}

# Symmetric Difference: Finds elements that are in either of the sets but not in both.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
sym_diff_set = set1 ^ set2
print(sym_diff_set)  # Output: {1, 2, 4, 5}

''' Set Comprehension

Like list comprehensions, sets can be created using set comprehensions for more concise code.
'''
# Example:

squares = {x**2 for x in range(6)}
print(squares)  # Output: {0, 1, 4, 9, 16, 25}

# Examples of Set Use Cases
# Removing Duplicates from a List

numbers = [1, 2, 2, 3, 4, 4, 5]
unique_numbers = set(numbers)
print(unique_numbers)  # Output: {1, 2, 3, 4, 5}

# Membership Testing


fruits = {'apple', 'banana', 'cherry'}
print('apple' in fruits)  # Output: True
print('orange' in fruits)  # Output: False

# Finding Common Elements in Multiple Collections

students_math = {'Alice', 'Bob', 'Charlie'}
students_science = {'Bob', 'Charlie', 'David'}
common_students = students_math & students_science
print(common_students)  # Output: {'Charlie', 'Bob'}

# Set Operations for Data Analysis

set_a = {1, 2, 3, 4, 5}
set_b = {4, 5, 6, 7, 8}
difference = set_a - set_b
print(difference)  # Output: {1, 2, 3}

# Insights
''' Sets in Python are highly useful for managing collections of unique items with
efficient membership testing and set operations.
Their key features include being unordered, containing unique elements, 
and supporting dynamic sizes and various set operations.'''
# Out:
# {1, 2, 3, 4}
# {1, 2, 3}
# {1, 3, 4}
# {1, 2, 3}
# {2, 3}
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}
# {0, 1, 4, 9, 16, 25}
# {1, 2, 3, 4, 5}
# True
# False
# {'Bob', 'Charlie'}
# {1, 2, 3}
# ' Sets in Python are highly useful for managing collections of unique items with\nefficient membership testing and set operations.\nTheir key features include being unordered, containing unique elements, \nand supporting dynamic sizes and various set operations.'

# %%
# Q 6.Discuss the use cases of tuples and sets in Python Programming.
''' ANS: Tuples and sets are both fundamental data structures in Python,
each serving distinct purposes and suited for different use cases.
Use cases:

Use Cases of Tuples
Immutable Data Structures

Scenario: When we need to store a fixed collection of items that should not be changed.
'''

# Example: Representing a point in 2D or 3D space.

point_2d = (3, 4)
point_3d = (1, 2, 3)

''' Data Records

Scenario: When we need to group related data that should remain unchanged.'''

# Example: Storing a record of a person’s information.

person = ('Alice', 30, 'Engineer')
name, age, profession = person

''' Dictionary Keys

Scenario: When we need to use a composite key for a dictionary. '''

# Example: Using tuples as keys for a dictionary.

coordinates = {(0, 0): 'Origin', (1, 2): 'Point A'}

''' Function Return Values

Scenario: When we need to return multiple values from a function. '''

# Example: Returning the quotient and remainder of a division.

def divide(x, y):
    return x // y, x % y

quotient, remainder = divide(10, 3)

''' Immutable Data for Hashing

Scenario: When we need data that can be used in a set or as a key in a dictionary.'''

# Example: Using tuples to store immutable sets of data.

unique_positions = {(1, 2), (3, 4), (5, 6)}

''' Efficient Packing and Unpacking

Scenario: When we need to efficiently pack and unpack data. '''

#Example: Returning multiple values from a function and unpacking them. 


def get_min_max(numbers):
    return (min(numbers), max(numbers))

min_val, max_val = get_min_max([1, 2, 3, 4, 5])


#  Use Cases of Sets

''' Removing Duplicates

Scenario: When we need to eliminate duplicate values from a collection.'''

# Example: Removing duplicates from a list.

numbers = [1, 2, 2, 3, 4, 4, 5]
unique_numbers = set(numbers)

''' Membership Testing

Scenario: When we need to efficiently test if an item is in a collection.'''

# Example: Checking if a user is part of a group.

active_users = {'alice', 'bob', 'charlie'}
print('alice' in active_users)  # Output: True

''' Set Operations (Union, Intersection, Difference)

Scenario: When we need to perform mathematical operations on sets of data.'''

# Example: Finding common elements between two sets.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
common_elements = set1 & set2  # Intersection

''' Efficient Data Management

Scenario: When we need a data structure optimized for fast membership 
tests and set operations.'''

#Example: Managing unique items or tags.

tags = {'python', 'programming', 'tutorial'}

''' Removing Invalid Entries

Scenario: When we need to remove invalid or erroneous entries efficiently.'''

# Example: Removing invalid entries from a list of data.

data = ['apple', '', 'banana', ' ', 'cherry']
valid_data = {item.strip() for item in data if item.strip()}

'''Mathematical Set Operations

Scenario: When we need to perform operations like union,
intersection, or difference.'''

# Example: Calculating the union of two sets of elements.

set_a = {1, 2, 3}
set_b = {3, 4, 5}
union_set = set_a | set_b
# Out:
# True

# %%
# Q 7. Describe how to add, modify and delete items in a dictionary with examples.
''' ANS: Overview of how to add, modify,and delete items in a Python dictionary:

1. Adding Items
We can add new key-value pairs to a dictionary by simply assigning a valueto a new key.
'''

# Example:

my_dict = {'a': 1, 'b': 2}

# Adding a new key-value pair
my_dict['c'] = 3
print(my_dict)  # Output: {'a': 1, 'b': 2, 'c': 3}

''' 2. Modifying Items
To modify the value associated with an existing key,
assign a new value to that key.'''

# Example:

my_dict = {'a': 1, 'b': 2}

# Modifying the value of an existing key
my_dict['b'] = 20
print(my_dict)  # Output: {'a': 1, 'b': 20}

''' 3. Deleting Items
We can delete items using several methods:'''

# del Statement: Removes a key-value pair by key.
# pop() Method: Removes and returns the value associated with a key.
# popitem() Method: Removes and returns an arbitrary key-value pair (in Python 3.7+ it removes the last inserted pair).
# clear() Method: Removes all items from the dictionary.

# Examples:

my_dict = {'a': 1, 'b': 2, 'c': 3}

# Using del statement
del my_dict['a']
print(my_dict)  # Output: {'b': 2, 'c': 3}

# Using pop() method
value = my_dict.pop('b')
print(value)    # Output: 2
print(my_dict)  # Output: {'c': 3}

# Using popitem() method
item = my_dict.popitem()
print(item)     # Output: ('c', 3)
print(my_dict)  # Output: {}

# Using clear() method
my_dict = {'a': 1, 'b': 2}
my_dict.clear()
print(my_dict)  # Output: {}

# Insights
''' Add Items: dict[key] = value
Modify Items: dict[key] = new_value
Delete Items: del dict[key], dict.pop(key), dict.popitem(), dict.clear() '''
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 20}
# {'b': 2, 'c': 3}
# 2
# {'c': 3}
# ('c', 3)
# {}
# {}
# ' Add Items: dict[key] = value\nModify Items: dict[key] = new_value\nDelete Items: del dict[key], dict.pop(key), dict.popitem(), dict.clear() '

# %%
# Q 8. Discuss the importance of dictionary keys being immutable and provide examples.
''' ANS : In Python, dictionary keys must be immutable because:

Hashability:
Importance: Dictionary keys must be hashable so that they can be used to quickly look up values in a hash table.
Immutable objects have a fixed hash value that doesn't change,
ensuring reliable and consistent access.'''

#Example: Strings and tuples are immutable and thus valid keys.

my_dict = {'name': 'Alice', 'age': 30}

''' Consistency:
Importance: Immutable keys ensure that the key-value association remains consistent throughout the dictionary's lifecycle.
If keys were mutable, changing a key’s value would affect the dictionary’s internal structure.
'''
# Example: Lists are mutable and cannot be used as dictionary keys.

# Invalid: Lists cannot be dictionary keys
my_dict = {[1, 2]: 'value'}  # Raises TypeError

# Examples of Valid and Invalid Dictionary Keys
# Valid Keys (Immutable):

# Strings as keys
my_dict = {'name': 'Alice'}

# Tuples as keys
my_dict = {(1, 2): 'point'}

# Invalid Keys (Mutable):

# Lists as keys
# Raises TypeError
my_dict = {[1, 2]: 'value'}

# Sets as keys
# Raises TypeError
my_dict = {{1, 2}: 'value'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 20
#      13 ''' Consistency:
#      14 Importance: Immutable keys ensure that the key-value association remains consistent throughout the dictionary's lifecycle.
#      15 If keys were mutable, changing a key’s value would affect the dictionary’s internal structure.
#      16 '''
#      17 # Example: Lists are mutable and cannot be used as dictionary keys.
#      18
#      19 # Invalid: Lists cannot be dictionary keys
# ---> 20 my_dict = {[1, 2]: 'value'}  # Raises TypeError
#      22 # Examples of Valid and Invalid Dictionary Keys
#      23 # Valid Keys (Immutable):
#      24
#      25 # Strings as keys
#      26 my_dict = {'name': 'Alice'}
#
# TypeError: unhashable type: 'list'
